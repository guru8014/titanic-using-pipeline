# %%
import pickle
import pandas as pd

# %%
pipe = pickle.load(open('rpipe.pkl','rb'))
columns=['Pclass','Sex','Age','SibSp','Parch','Fare','Embarked']

# %%
#test = pd.DataFrame([[3,'female',47.0,1,0,7.0000,'S']],columns=columns,dtype=object)

# %%
#pipe.predict(test)

# %%
print('ENTER Pclass,Sex,Age,SibSp,Parch,Fare,Embarked')
# Out:
# ENTER Pclass,Sex,Age,SibSp,Parch,Fare,Embarked

# %%
test = pd.DataFrame([[input(int()),input(str()),input(float()),input(int()),input(int()),input(float()),input(str())]],columns=columns,dtype=object)
# Out:
# 0 3
#  female
# 0.0 47.0
# 0 1
# 0 0
# 0.0 7.0000
#  S

# %%
pipe.predict(test)
# Out:
# array([0])
